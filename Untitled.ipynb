# %%
import requests

API_KEY = "9d9a703569914e82a61aa211e31ddba1"
url = "https://newsapi.org/v2/everything"

params = {
    "q": "job market hiring employment",
    "language": "en",
    "sortBy": "publishedAt",
    "pageSize": 100,
    "apiKey": API_KEY
}

response = requests.get(url, params=params)
data = response.json()

print("Status:", data["status"])
print("Total articles found:", data["totalResults"])
# Out:
# Status: ok
# Total articles found: 292

# %%
import pandas as pd

articles = data["articles"]
df = pd.DataFrame(articles)

print(df.shape)
df.head()
# Out:
# (97, 8)
#                                               source          author  \
# 0            {'id': None, 'name': 'Crypto Briefing'}  Editorial Team
# 1         {'id': None, 'name': 'New Zealand Herald'}   Bijou Johnson
# 2                 {'id': None, 'name': 'PRNewswire'}            None
# 3  {'id': 'the-times-of-india', 'name': 'The Time...  Sreeradha Basu
# 4               {'id': 'fortune', 'name': 'Fortune'}  Sheryl Estrada
#
#                                                title  \
# 0  Meta launches $115M America’s Workforce Academ...
# 1  Bay of Plenty records highest unemployment rat...
# 2  Global Hiring Outlook Holds Steady in Q3 With ...
# 3  Flexi-staffing industry in India sees 8% YoY g...
# 4  The man behind Claude Code says you’re compari...
#
#                                          description  \
# 0  Meta's initiative may set a new standard for w...
# 1  Recruiters report more cautious employers and ...
# 2  Employers cite economic uncertainty, above AI,...
# 3  The push for formal employment, strongly suppo...
# 4  Boris Cherny says most companies are asking th...
#
#                                                  url  \
# 0  https://cryptobriefing.com/meta-workforce-acad...
# 1  https://www.nzherald.co.nz/bay-of-plenty-times...
# 2  https://www.prnewswire.com/news-releases/globa...
# 3  https://economictimes.indiatimes.com/jobs/hr-p...
# 4  https://fortune.com/2026/06/09/boris-cherny-cl...
#
#                                           urlToImage           publishedAt  \
# 0  https://static.cryptobriefing.com/wp-content/u...  2026-06-09T22:36:59Z
# 1  https://www.nzherald.co.nz/resizer/v2/XNKVDLGB...  2026-06-09T18:00:00Z
# 2  https://mmx.prnewswire.com/media/MS409711/Manp...  2026-06-09T13:31:00Z
# 3  https://img.etimg.com/thumb/msid-131611910,wid...  2026-06-09T12:55:19Z
# 4  https://fortune.com/img-assets/wp-content/uplo...  2026-06-09T10:37:11Z
#
#                                              content
# 0  The five-week program covers everything from t...
# 1  He said Bay of Plenty unemployment usually inc...
# 2  Yet beneath the headline number, a more comple...
# 3  Bengaluru: Indias flexi-staffing industry has ...
# 4  Good morning. Five years after its founding, A...

# %%
df.to_csv("job_market_news.csv", index=False)
print("Saved!")
# Out:
# Saved!
